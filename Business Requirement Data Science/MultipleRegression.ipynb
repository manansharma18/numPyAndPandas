# %%
import numpy as np
import pandas as pd
import sklearn 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from pylab import rcParams
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10,8

# %%
import seaborn as sb
sb.set_style('whitegrid')
from collections import Counter

# %%
address = '/Users/manansharma/Documents/Python/Business Requirement Data Science/enrollment_forecast.csv'
enrollData = pd.read_csv(address)
enrollData.columns = ['year','roll','unem','hgrad','inc']
enrollData.head()
# Out:
#    year  roll  unem  hgrad   inc
# 0     1  5501   8.1   9552  1923
# 1     2  5945   7.0   9680  1961
# 2     3  6629   7.3   9731  1979
# 3     4  7556   7.5  11666  2030
# 4     5  8716   7.0  14675  2112

# %%
sb.pairplot(enrollData)

# %%
print(enrollData.corr())
# Out:
# year      roll      unem     hgrad       inc
# year   1.000000  0.900934  0.378305  0.670300  0.944287
# roll   0.900934  1.000000  0.391344  0.890294  0.949876
# unem   0.378305  0.391344  1.000000  0.177376  0.282310
# hgrad  0.670300  0.890294  0.177376  1.000000  0.820089
# inc    0.944287  0.949876  0.282310  0.820089  1.000000

# %% [markdown]
# This is to show that predictors are not dependent on each other. Checking for unem and hgrad.

# %%
data = enrollData[['unem','hgrad']].values
target = enrollData['roll']
dataLabel = ['unem','hgrad']

# %%
linReg = LinearRegression()
linReg.fit(data,target)
print(linReg.coef_)
# Out:
# [698.26813163   0.94227685]

# %%
print(linReg.score(data,target))
# Out:
# 0.8488812666133723

# %%
plt.plot(data,target,'r^')

# %%
print(linReg.predict(np.array([[9,10000]])))
# Out:
# [7451.43067189]
